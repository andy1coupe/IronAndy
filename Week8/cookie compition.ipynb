# %%
import pandas as pd
import numpy as np
import pyxlsb

# %%
df = pd.read_csv('cookies_comp_students.csv')

# %%
df1=pd.read_csv('cookies_comp_studentstest.csv')

# %%
df
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                     0.25          9.5        300        15.0     136.0
# 1                     0.23          3.3        520        34.0     113.0
# 2                     0.18          1.9        360        33.0     106.0
# 3                     0.18         10.5        490        41.0     124.0
# 4                     0.24          2.4        770         6.0      33.0
# ...                    ...          ...        ...         ...       ...
# 5193                  0.66          2.0        390        15.0      88.0
# 5194                  0.16          1.5        490        10.0      97.0
# 5195                  0.25         14.3        480        79.0     149.0
# 5196                  0.33          1.4        560        35.0     136.0
# 5197                  0.44          1.8        810        28.0      68.0
#
#       density    pH  grams baking soda  bake time  quality butter type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5198 entries, 0 to 5197
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sugar to flour ratio  5198 non-null   float64
#  1   sugar index           5193 non-null   float64
#  2   bake temp             5198 non-null   int64
#  3   chill time            5198 non-null   float64
#  4   calories              5198 non-null   float64
#  5   density               5198 non-null   float64
#  6   pH                    5198 non-null   float64
#  7   grams baking soda     5198 non-null   float64
#  8   bake time             5188 non-null   float64
#  9   quality               5198 non-null   int64
#  10  butter type           5198 non-null   object
#  11  weight                5198 non-null   float64
#  12  diameter              5198 non-null   int64
#  13  mixins                5196 non-null   object
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                     0.25          9.5        300        15.0     136.0
# 1                     0.23          3.3        520        34.0     113.0
# 2                     0.18          1.9        360        33.0     106.0
# 3                     0.18         10.5        490        41.0     124.0
# 4                     0.24          2.4        770         6.0      33.0
# ...                    ...          ...        ...         ...       ...
# 5193                  0.66          2.0        390        15.0      88.0
# 5194                  0.16          1.5        490        10.0      97.0
# 5195                  0.25         14.3        480        79.0     149.0
# 5196                  0.33          1.4        560        35.0     136.0
# 5197                  0.44          1.8        810        28.0      68.0
#
#       density    pH  grams baking soda  bake time  quality butter type  \
# ...

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df[df.duplicated(keep=False)]
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 34                    0.36         13.2        670        53.0     178.0
# 147                   0.30         12.8        620        19.0     171.0
# 1143                  0.29         10.5        400        21.0     145.0
# 1429                  0.43          1.6        350        31.0     128.0
# 1600                  0.00          1.8        500        27.0      63.0
# 1850                  0.32          3.6        350        22.0      93.0
# 2024                  0.35         15.3        560        31.0     117.0
# 3022                  0.30          1.6        450        36.0     139.0
# 3076                  0.35         13.5        380        49.0     118.0
# 3115                  0.13          4.5        390        17.0     116.0
# 3259                  0.29         10.5        400        21.0     145.0
# 3294                  0.45          8.3        500        52.0     196.0
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                     0.25          9.5        300        15.0     136.0
# 1                     0.23          3.3        520        34.0     113.0
# 2                     0.18          1.9        360        33.0     106.0
# 3                     0.18         10.5        490        41.0     124.0
# 4                     0.24          2.4        770         6.0      33.0
# ...                    ...          ...        ...         ...       ...
# 5193                  0.66          2.0        390        15.0      88.0
# 5194                  0.16          1.5        490        10.0      97.0
# 5195                  0.25         14.3        480        79.0     149.0
# 5196                  0.33          1.4        560        35.0     136.0
# 5197                  0.44          1.8        810        28.0      68.0
#
#       density    pH  grams baking soda  bake time  quality butter type  \
# ...

# %%
df_num=df.drop(columns=['butter type', 'mixins'])

# %%
df1.head()
# Out:
#      id  sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0  1001                  0.62        19.25        400        41.0     172.0
# 1  1002                  0.35         1.00        520        35.0     146.0
# 2  1003                  0.39        10.40        440        20.0     142.0
# 3  1004                  0.33         1.10        570        21.0      82.0
# 4  1005                  0.37        13.50        600        52.0     192.0
#
#    density    pH  grams baking soda  bake time  quality butter type  weight  \
# 0   1.0002  7.98               0.67        9.7        0      melted    16.6
# 1   0.9930  8.45               0.44       10.0        0      melted    13.8
# 2   0.9974  8.20               0.53       10.0        0      melted    17.0
# 3   0.9910  8.32               0.46       10.9        0      melted    12.4
# 4   0.9975  8.00               0.44        9.1        0      melted    14.8
#
# ...

# %%
df.head()
# Out:
#    sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0                  0.25          9.5        300        15.0     136.0
# 1                  0.23          3.3        520        34.0     113.0
# 2                  0.18          1.9        360        33.0     106.0
# 3                  0.18         10.5        490        41.0     124.0
# 4                  0.24          2.4        770         6.0      33.0
#
#    density    pH  grams baking soda  bake time  quality butter type  weight  \
# 0  0.99367  8.10               0.44       12.1        8      melted    15.2
# 1  0.99429  8.16               0.48        8.4        7      melted    12.4
# 2  0.98746  8.21               0.83       14.0        9      melted     9.4
# 3  0.99630  8.14               0.35       10.5        7      melted    12.2
# 4  0.99740  8.09               0.57        9.4        5       cubed    19.8
#
#    diameter                 mixins  crunch factor  aesthetic appeal
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#        id  sugar to flour ratio  sugar index  bake temp  chill time  calories  \
# 0    1001                  0.62        19.25        400        41.0     172.0
# 1    1002                  0.35         1.00        520        35.0     146.0
# 2    1003                  0.39        10.40        440        20.0     142.0
# 3    1004                  0.33         1.10        570        21.0      82.0
# 4    1005                  0.37        13.50        600        52.0     192.0
# ..    ...                   ...          ...        ...         ...       ...
# 774  1775                  0.02         1.90        780        18.0      30.0
# 775  1776                  0.19         5.20        940        19.0      98.0
# 776  1777                  0.00         2.10        600         6.0      13.0
# 777  1778                  0.08         2.30        670        19.0      32.0
# 778  1779                  0.50        13.80       2050        48.0      82.0
#
# ...

# %%
df_test=df1.drop(columns=['butter type', 'mixins', 'id'])

# %%
from sklearn.linear_model import LinearRegression as Lin

# %%
y=df_num['quality']
X=df_num.drop(['quality','aesthetic appeal', 'crunch factor', 'diameter', 'weight', 'pH'],axis=1)

# %%
y_test=df_test['quality']
X_test=df_test.drop(['quality','aesthetic appeal', 'crunch factor', 'diameter', 'weight', 'pH'],axis=1)

# %%
y_test.value_counts()
# Out:
# 0    779
# Name: quality, dtype: int64

# %%
linreg=Lin()

# %%
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)

# %%
y_train_pred=linreg.predict(X)

# %%
y_train_pred
# Out:
# array([8.43021582, 6.34785947, 8.46819459, ..., 7.92379515, 7.10673147,
#        6.96422329])

# %%
y
# Out:
# 0       8
# 1       7
# 2       9
# 3       7
# 4       5
#        ..
# 5193    6
# 5194    8
# 5195    7
# 5196    8
# 5197    5
# Name: quality, Length: 5169, dtype: int64

# %%
r2(y,y_train_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8ecbc043669c> in <module>
# ----> 1 r2(y,y_train_pred)
#
# NameError: name 'r2' is not defined

# %%
y_val=linreg.predict(X_test)

# %%
y_val
# Out:
# array([ 8.17253229,  7.38213635,  7.56143858,  7.13362658,  7.76237344,
#         7.2600752 ,  7.21176721,  7.70078705,  8.42011875,  7.68888095,
#         7.30090735,  7.7476906 ,  7.33521202,  7.21418738,  7.79685108,
#         7.18730133,  7.61966257,  6.98071146,  7.91494315,  7.82590989,
#         7.26154573,  8.02173472,  7.77764503,  8.26828236,  7.3621276 ,
#         7.89379115,  7.6053896 ,  7.37741806,  8.00188597,  7.52525795,
#         8.15430885,  8.358902  ,  8.18169925,  8.08870269,  8.05518728,
#         6.95560681,  8.63345487,  7.62120257,  7.16547073,  7.28648392,
#         7.92194105,  6.38046828,  7.64821506,  7.30790777,  6.89727595,
#         8.11498361,  7.23713636,  7.80342618,  7.4476005 ,  6.78731906,
#         7.68545281,  7.92060462,  7.72754466,  7.32938217,  7.23458116,
#         7.5988333 ,  7.93000758,  7.02488647,  8.27159232,  8.42519507,
#         8.39339359,  7.84810402,  7.65386412,  7.92967609,  7.73967705,
# ...

# %%
from sklearn.metrics import r2_score as r2
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae

# %%
r2(y_test, y_pred)
# Out:
# 0.0

# %%
mse(y_test, y_pred)
# Out:
# 58.54965139274604

# %%
mae(y_test,y_pred)
# Out:
# 7.618693799280129

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Knn=KNeighborsClassifier(n_neighbors=5)

# %%
Knn.fit(X, y)
# Out:
# KNeighborsClassifier()

# %%
y_pred=Knn.predict(X_test)

# %%
y_pred
# Out:
# array([ 8,  7,  8,  8,  7,  9,  8,  8,  7,  7,  8,  8,  9,  7,  8,  8,  8,
#         8,  7,  9,  8,  8,  9,  7,  8,  7,  8,  7,  7,  8,  7,  7,  8,  8,
#         8,  8,  7,  8,  7,  8,  9,  6,  7,  8,  5,  8,  8,  8,  8,  6,  7,
#         7,  9,  8,  8,  7,  8,  8,  8,  8,  8,  9,  8,  7,  8,  8,  8,  7,
#         6,  9,  8,  9,  8,  7,  8,  8,  8,  7,  7,  8,  8,  7,  7,  9, 10,
#         8,  8,  8,  8,  8,  8,  8,  7,  8,  8,  8,  7,  8,  9,  7, 10,  8,
#         9,  8,  8,  8,  8,  8,  7,  8,  7,  7,  7,  7,  8,  7,  7,  7,  8,
#         7,  9,  7,  7,  8,  5,  8,  7,  7,  7,  8,  7,  8,  7,  8,  7,  9,
#         8, 10,  9,  9,  9,  9,  7,  7,  7,  9,  7,  8,  8,  8,  7,  8,  7,
#         8,  7,  8,  8,  7,  8,  9,  8,  8,  7,  8,  8,  7,  7,  7,  7,  9,
#         9,  8,  7,  9,  7,  8,  8,  8,  8,  9,  7,  6,  8,  8,  8,  8,  9,
#         7,  7,  8,  7,  8,  9,  7,  8,  6,  7,  7,  8,  8,  8,  8,  8,  8,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
clf=rfc(n_estimators=50, max_depth=5,random_state=40)
clf.fit(X,y)
print(clf.score(X_test,y_test))
# Out:
# 0.0

# %%
from sklearn.model_selection import cross_val_score
cross_val_scores=cross_val_score(clf,X_test,y_pred,cv=10)
np.mean(cross_val_scores)
# Out:
# /Users/macbookpro/opt/anaconda3/envs/andyclass/lib/python3.6/site-packages/sklearn/model_selection/_split.py:668: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# 0.51988011988012

# %%
feature_importances=clf.feature_importances_

# %%
feature_names = X.columns

# %%
forest_importances = pd.Series(feature_importances, index=feature_names)

# %%
forest_importances
# Out:
# sugar to flour ratio    0.060652
# sugar index             0.063399
# bake temp               0.253533
# chill time              0.062574
# calories                0.232194
# density                 0.140560
# grams baking soda       0.043732
# bake time               0.143356
# dtype: float64
